# %% [markdown]
# There is a LOT of CReSIS data.
#
# I need to move towards creating an index from filename -> URL for the eventual QGIS layer, so might as well start with that now.

# %%
cresis_url = "https://data.cresis.ku.edu/data/rds"

# %%
from bs4 import BeautifulSoup   # For parsing html and extracting the links
import pathlib
import re
import requests  # For downloading index page
import subprocess

# %%
reqs = requests.get(cresis_url)
soup = BeautifulSoup(reqs.text, 'html.parser')

all_urls = [link.get('href') for link in soup.find_all('a')]
# print(all_urls)
# download_urls = [base_url + url for url in all_urls if url.startswith(prefix)]
#filenames = [url.strip(base_url+prefix).split('?')[0] for url in download_urls]

# Each campaign seems to have two links, but we only want one.
campaigns = set()
for link in soup.find_all('a'):
    href = link.get('href')
    try:
        year = int(href[0:4])  # valid campaign names start with YYYY.
    except:
        continue
    campaign = href.strip('/')
    campaigns.add(campaign)

campaigns = list(campaigns)
campaigns.sort()

# TODO: Fix this terrible nested dictionary 
cresis_datafiles = {"ANTARCTIC":{}, "ARCTIC":{}}

for campaign in campaigns:
    print()
    print(campaign)
    if "Antarctica" in campaign:
        region = "ANTARCTIC"
    else:
        region = "ARCTIC"
    cresis_datafiles[region][campaign] = {}
        
    campaign_url = "{}/{}".format(cresis_url, campaign)
    reqs = requests.get(campaign_url)
    soup = BeautifulSoup(reqs.text, 'html.parser')
    dirs = [link.get('href').strip('/') for link in soup.find_all('a')]
    # From their README: "The standard L1B files are, in order of increasing quality
    # CSARP_qlook, CSARP_csarpcombined, CSARP_standard, and CSARP_mvdr directories. 
    product_priorities = ["CSARP_mvdr", "CSARP_standard", "CSARP_csarp-combined", "CSARP_qlook"]
    product = None
    for pp in product_priorities:
        if pp in dirs:
            product = pp
            break
    print("Product: {}".format(product))
    cresis_datafiles[region][campaign][product] = {}

            
    product_url = "{}/{}".format(campaign_url, product)
    reqs = requests.get(product_url)
    soup = BeautifulSoup(reqs.text, 'html.parser')
    segments = set()
    for link in soup.find_all('a'):
        href = link.get('href').strip('/')
        try:
            date, seg = map(int, href.split('_'))
            segments.add(href)
        except:
            continue
        
    segments = list(segments)
    segments.sort()
    
    for segment in segments:
        segment_url = "{}/{}".format(product_url, segment)
        reqs = requests.get(segment_url)
        soup = BeautifulSoup(reqs.text, 'html.parser')
        files = set()
        combined_regex = "Data_[0-9]{8}_[0-9]{2}_[0-9]{3}.mat"
        for link in soup.find_all('a'):
            href = link.get('href').strip('/')
            if re.match(combined_regex, href) is not None:
                files.add(href)
        files = list(files)
        files.sort()
        
        cresis_datafiles[region][campaign][product][segment] = {file: "{}/{}".format(segment_url, file) for file in files}
# Out:
# 1993_Greenland_P3
# Product: CSARP_standard
#
# 1995_Greenland_P3
# Product: CSARP_standard
#
# 1996_Greenland_P3
# Product: CSARP_standard
#
# 1997_Greenland_P3
# Product: CSARP_standard
#
# 1998_Greenland_P3
# Product: CSARP_standard
#
# 1999_Greenland_P3
# Product: CSARP_standard
#
# 2001_Greenland_P3
# Product: CSARP_standard
#
# 2002_Antarctica_P3chile
# Product: CSARP_standard
#
# 2002_Greenland_P3
# Product: CSARP_standard
#
# 2003_Greenland_P3
# Product: CSARP_standard
#
# 2004_Antarctica_P3chile
# Product: CSARP_standard
#
# 2005_Antarctica_GPRWAIS
# Product: CSARP_standard
#
# 2005_Greenland_TO
# Product: CSARP_standard
#
# 2006_Greenland_TO
# Product: CSARP_mvdr
#
# 2007_Greenland_P3
# Product: CSARP_standard
#
# 2008_Greenland_Ground
# Product: CSARP_mvdr
#
# 2008_Greenland_TO
# Product: CSARP_mvdr
#
# 2009_Antarctica_DC8
# Product: CSARP_mvdr
#
# 2009_Antarctica_TO
# Product: CSARP_standard
#
# 2009_Antarctica_TO_Gambit
# Product: CSARP_standard
#
# 2009_Greenland_TO
# Product: CSARP_mvdr
#
# 2010_Antarctica_DC8
# Product: CSARP_mvdr
#
# 2010_Greenland_DC8
# Product: CSARP_mvdr
#
# 2010_Greenland_P3
# Product: CSARP_mvdr
#
# 2011_Antarctica_DC8
# Product: CSARP_mvdr
#
# 2011_Antarctica_TO
# Product: CSARP_mvdr
#
# 2011_Greenland_P3
# Product: CSARP_csarp-combined
#
# 2011_Greenland_TO
# Product: CSARP_csarp-combined
#
# 2012_Antarctica_DC8
# Product: CSARP_mvdr
#
# 2012_Greenland_P3
# Product: CSARP_mvdr
#
# 2013_Antarctica_Basler
# Product: CSARP_mvdr
#
# 2013_Antarctica_P3
# Product: CSARP_mvdr
#
# 2013_Greenland_P3
# Product: CSARP_mvdr
#
# 2014_Antarctica_DC8
# Product: CSARP_mvdr
#
# 2014_Greenland_P3
# Product: CSARP_mvdr
#
# 2015_Greenland_C130
# Product: CSARP_standard
#
# 2016_Antarctica_DC8
# Product: CSARP_mvdr
#
# 2016_Greenland_G1XB
# Product: CSARP_standard
#
# 2016_Greenland_P3
# Product: CSARP_standard
#
# 2016_Greenland_Polar6
# Product: CSARP_standard
#
# 2016_Greenland_TOdtu
# Product: CSARP_standard
#
# 2017_Antarctica_Basler
# Product: CSARP_standard
#
# 2017_Antarctica_P3
# Product: CSARP_mvdr
#
# 2017_Greenland_P3
# Product: CSARP_mvdr
#
# 2018_Antarctica_DC8
# Product: CSARP_mvdr
#
# 2018_Antarctica_Ground
# Product: CSARP_standard
#
# 2018_Greenland_P3
# Product: CSARP_mvdr
#
# 2019_Antarctica_GV
# Product: CSARP_mvdr
#
# 2019_Greenland_P3
# Product: CSARP_standard

# %%
# TODO: Want to save the index, because simply creating it takes quite a while.

# %%
import pickle
with open("cresis_datafiles.pkl", 'wb') as fp:
    pickle.dump(cresis_datafiles, fp)

# %%
# NB: looks like combined is CSARP_csarp-combined and not CSARP_csarpcombined. So far, only relevant for 2011_Greenland_{P3, TO}

# %%
for region, campaigns in cresis_datafiles.items():
    print(region)
    for campaign, products in campaigns.items():
        print(campaign)
        print(".. {}".format(product))
        for product, segments in products.items():
            for segment, frames in segments.items():
                print(".... {}".format(segment))
                dest_dir = "/Volumes/RadarData/{}/CRESIS/{}/{}/{}".format(region, campaign, product, segment)
                try:
                    pp = pathlib.Path(dest_dir)
                    pp.mkdir(parents=True, exist_ok=True)
                except FileExistsError as ex:
                    raise Exception("Could not create {}.".format(dest_dir))
                    continue
    
                for frame, data_url in frames.items():
                    wget_cmd = 'wget -c --directory-prefix="{}" "{}"'.format(dest_dir, data_url) 
                    print(wget_cmd)
                    output = subprocess.getoutput(wget_cmd)
                    #break  # we're just testing right now ... don't grab everything!
                break
# Out:
# ANTARCTIC
# 2002_Antarctica_P3chile
# .. CSARP_standard
# .... 20021126_01
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_002.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_004.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_005.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_006.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_007.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_008.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_009.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_010.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_011.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_012.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_013.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2002_Antarctica_P3chile/CSARP_standard/20021126_01" "https://data.cresis.ku.edu/data/rds/2002_Antarctica_P3chile/CSARP_standard/20021126_01/Data_20021126_01_014.mat"
# 2004_Antarctica_P3chile
# .. CSARP_standard
# .... 20041118_01
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_002.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_004.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_005.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_006.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_007.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_008.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_009.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_010.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_011.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_012.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_013.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_014.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_015.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_016.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_017.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_018.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_019.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_020.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_021.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_022.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_023.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_024.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_025.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_026.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_027.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_028.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_029.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_030.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_031.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_032.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_033.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_034.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_035.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_036.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_037.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2004_Antarctica_P3chile/CSARP_standard/20041118_01" "https://data.cresis.ku.edu/data/rds/2004_Antarctica_P3chile/CSARP_standard/20041118_01/Data_20041118_01_038.mat"
# 2005_Antarctica_GPRWAIS
# .. CSARP_standard
# .... 20060103_01
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2005_Antarctica_GPRWAIS/CSARP_standard/20060103_01" "https://data.cresis.ku.edu/data/rds/2005_Antarctica_GPRWAIS/CSARP_standard/20060103_01/Data_20060103_01_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2005_Antarctica_GPRWAIS/CSARP_standard/20060103_01" "https://data.cresis.ku.edu/data/rds/2005_Antarctica_GPRWAIS/CSARP_standard/20060103_01/Data_20060103_01_002.mat"
# 2009_Antarctica_DC8
# .. CSARP_standard
# .... 20091016_01
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_002.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_004.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_005.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_006.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_007.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_008.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_009.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_010.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_011.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_012.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_013.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_014.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_015.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_016.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_017.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_018.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_019.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_020.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_021.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_022.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_023.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_024.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_025.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_026.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_027.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_028.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_029.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_030.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_031.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_032.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_033.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_034.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_035.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_036.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_037.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_038.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_039.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_040.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_041.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_042.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_043.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_044.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_045.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_046.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_047.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_DC8/CSARP_mvdr/20091016_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_DC8/CSARP_mvdr/20091016_01/Data_20091016_01_048.mat"
# 2009_Antarctica_TO
# .. CSARP_mvdr
# .... 20091224_01
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_002.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_004.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_005.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_006.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_007.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_008.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_009.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_010.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_011.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_012.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_013.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_014.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_015.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_016.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_017.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_018.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_019.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_020.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_021.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_022.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_023.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_024.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_025.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO/CSARP_standard/20091224_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO/CSARP_standard/20091224_01/Data_20091224_01_026.mat"
# 2009_Antarctica_TO_Gambit
# .. CSARP_standard
# .... 20081223_01
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_002.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_004.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_005.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_006.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_007.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_008.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_009.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_010.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_011.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_012.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_013.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_014.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_015.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_016.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_017.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_018.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_019.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_020.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_021.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_022.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_023.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_024.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_025.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_026.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01" "https://data.cresis.ku.edu/data/rds/2009_Antarctica_TO_Gambit/CSARP_standard/20081223_01/Data_20081223_01_027.mat"
# 2010_Antarctica_DC8
# .. CSARP_standard
# .... 20101026_02
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2010_Antarctica_DC8/CSARP_mvdr/20101026_02" "https://data.cresis.ku.edu/data/rds/2010_Antarctica_DC8/CSARP_mvdr/20101026_02/Data_20101026_02_022.mat"
# 2011_Antarctica_DC8
# .. CSARP_mvdr
# .... 20111012_41
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_DC8/CSARP_mvdr/20111012_41" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_DC8/CSARP_mvdr/20111012_41/Data_20111012_41_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_DC8/CSARP_mvdr/20111012_41" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_DC8/CSARP_mvdr/20111012_41/Data_20111012_41_002.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_DC8/CSARP_mvdr/20111012_41" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_DC8/CSARP_mvdr/20111012_41/Data_20111012_41_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_DC8/CSARP_mvdr/20111012_41" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_DC8/CSARP_mvdr/20111012_41/Data_20111012_41_004.mat"
# 2011_Antarctica_TO
# .. CSARP_mvdr
# .... 20111129_06
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_002.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_004.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_005.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_006.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_007.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_008.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_009.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_010.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_011.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_012.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_013.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_014.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_015.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_016.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_017.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_018.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2011_Antarctica_TO/CSARP_mvdr/20111129_06" "https://data.cresis.ku.edu/data/rds/2011_Antarctica_TO/CSARP_mvdr/20111129_06/Data_20111129_06_019.mat"
# 2012_Antarctica_DC8
# .. CSARP_mvdr
# .... 20121012_03
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_002.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_004.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_005.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_006.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_007.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_008.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_009.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_010.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_011.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_012.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_013.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_014.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_015.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_016.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_017.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_018.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_019.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_020.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_021.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_022.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_023.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_024.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_025.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_026.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_027.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_028.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_029.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_030.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_031.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_032.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_033.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_034.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ANTARCTIC/CRESIS/2012_Antarctica_DC8/CSARP_mvdr/20121012_03" "https://data.cresis.ku.edu/data/rds/2012_Antarctica_DC8/CSARP_mvdr/20121012_03/Data_20121012_03_035.mat"
# ...
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_004.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_005.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_006.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_007.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_008.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_009.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_010.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_011.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_012.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_013.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_014.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_015.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_016.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_Polar6/CSARP_standard/20160512_02" "https://data.cresis.ku.edu/data/rds/2016_Greenland_Polar6/CSARP_standard/20160512_02/Data_20160512_02_017.mat"
# 2016_Greenland_TOdtu
# .. CSARP_standard
# .... 20161101_01
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_TOdtu/CSARP_standard/20161101_01" "https://data.cresis.ku.edu/data/rds/2016_Greenland_TOdtu/CSARP_standard/20161101_01/Data_20161101_01_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_TOdtu/CSARP_standard/20161101_01" "https://data.cresis.ku.edu/data/rds/2016_Greenland_TOdtu/CSARP_standard/20161101_01/Data_20161101_01_002.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_TOdtu/CSARP_standard/20161101_01" "https://data.cresis.ku.edu/data/rds/2016_Greenland_TOdtu/CSARP_standard/20161101_01/Data_20161101_01_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2016_Greenland_TOdtu/CSARP_standard/20161101_01" "https://data.cresis.ku.edu/data/rds/2016_Greenland_TOdtu/CSARP_standard/20161101_01/Data_20161101_01_004.mat"
# 2017_Greenland_P3
# .. CSARP_standard
# .... 20170322_03
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2017_Greenland_P3/CSARP_mvdr/20170322_03" "https://data.cresis.ku.edu/data/rds/2017_Greenland_P3/CSARP_mvdr/20170322_03/Data_20170322_03_001.mat"
# 2018_Greenland_P3
# .. CSARP_mvdr
# .... 20180404_02
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2018_Greenland_P3/CSARP_mvdr/20180404_02" "https://data.cresis.ku.edu/data/rds/2018_Greenland_P3/CSARP_mvdr/20180404_02/Data_20180404_02_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2018_Greenland_P3/CSARP_mvdr/20180404_02" "https://data.cresis.ku.edu/data/rds/2018_Greenland_P3/CSARP_mvdr/20180404_02/Data_20180404_02_002.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2018_Greenland_P3/CSARP_mvdr/20180404_02" "https://data.cresis.ku.edu/data/rds/2018_Greenland_P3/CSARP_mvdr/20180404_02/Data_20180404_02_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2018_Greenland_P3/CSARP_mvdr/20180404_02" "https://data.cresis.ku.edu/data/rds/2018_Greenland_P3/CSARP_mvdr/20180404_02/Data_20180404_02_004.mat"
# 2019_Greenland_P3
# .. CSARP_mvdr
# .... 20190403_02
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_001.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_002.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_003.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_004.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_005.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_006.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_007.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_008.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_009.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_010.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_011.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_012.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_013.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_014.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_015.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_016.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_017.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_018.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_019.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_020.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_021.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_022.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_023.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_024.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_025.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_026.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_027.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_028.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_029.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_030.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_031.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_032.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_033.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_034.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_035.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_036.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_037.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_038.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_039.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_040.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_041.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_042.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_043.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_044.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_045.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_046.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_047.mat"
# wget -c --directory-prefix="/Volumes/RadarData/ARCTIC/CRESIS/2019_Greenland_P3/CSARP_standard/20190403_02" "https://data.cresis.ku.edu/data/rds/2019_Greenland_P3/CSARP_standard/20190403_02/Data_20190403_02_048.mat"

# %%
https://data.cresis.ku.edu/data/rds/1993_Greenland_P3/
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']
